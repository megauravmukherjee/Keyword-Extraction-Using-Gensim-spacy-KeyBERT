# %%
raw_data= open('7.txt').read()
raw_data
# Out:
# ' VanDyke SecureCRT and SecureFX 2021 Free Download     VanDyke SecureCRT and SecureFX 2021 Free Download. It is full offline installer standalone setup of VanDyke SecureCRT and SecureFX 2021.VanDyke SecureCRT and SecureFX 2021 OverviewVanDyke SecureFX is a high-speed and secure file transfer application that provides the network administrators with secure remote access, file transfer, and data tunneling across a network. It is a reliable tool that offers robust security of SSH, extensive session management, and advanced scripting capabilities allowing you to raise your productivity to the next high level.The program offers advanced site synchronization and automation features to help web designers and network administrators streamline everyday tasks.The program supports a wide range of popular protocols such as SSH2, SFTP, FTP/TLS, SCP thus providing maximum\xa0 flexibility when connecting to a range of remote servers.\xa0 It has an easy to use, Explorer-like interface with full support for drag-and-drop file transfers to and from the desktop and other applications. You can also download Frostwire Free Download File Sharing Application.VanDyke SecureFX is an excellent application which offers a wide range of useful features and options that are responsible for configuring general software and data transfer protocols.It uses a variety of reliable and robust algorithms such as AES, Twofish, Blowfish, 3DES, and RC4 to ensure strong data encryption.Thus it empowers you to automate secure file transfers, synchronize local and remote files, and perform server-to-server transfers. It also facilitates encrypted logons and provides flexible authentication options to ensure the integrity of each message sent over the network.The program offers support for multiple platforms allowing you to apply the strong encryption and authentication mechanism of Secure Shell protocol for secure network administration and end user access. It also supports relentless file transfers that automatically reconnect and resume when transfer connections are broken. You can also download FileZilla Pro 2021 Free Download.VanDyke SecureCRT and SecureFX 2021 FeaturesBelow are some noticeable features which you will experience after VanDyke SecureCRT and SecureFX 2021 Free Download     High-speed and secure file transfer application that provides the network administrators with secure remote access, file transfer, and data tunneling across a network.Reliable tool that offers robust security of SSH, extensive session management, and advanced scripting capabilities allowing you to raise your productivity to the next high level.Offers advanced site synchronization and automation features to help web designers and network administrators streamline everyday tasks.Supports a wide range of popular protocols such as SSH2, SFTP, FTP/TLS, SCP thus providing maximum\xa0 flexibility when connecting to a range of remote servers.Has got an easy to use, Explorer-like interface with full support for drag-and-drop file transfers to and from the desktop and other applications.Provides a wide range of useful features and options that are responsible for configuring general software and data transfer protocols.Uses a variety of reliable and robust algorithms such as AES, Twofish, Blowfish, 3DES, and RC4 to ensure strong data encryption.Empowers you to automate secure file transfers, synchronize local and remote files, and perform server-to-server transfers.Facilitates encrypted logons and provides flexible authentication options to ensure the integrity of each message sent over the network.Offers support for multiple platforms allowing you to apply the strong encryption and authentication mechanism of Secure Shell protocol for secure network administration and end user access.Supports relentless file transfers that automatically reconnect and resume when transfer connections are broken.VanDyke SecureCRT and SecureFX 2021 Technical Setup DetailsPrior to start VanDyke SecureCRT and Se ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings

import re
import nltk
from wordcloud import WordCloud
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.metrics import confusion_matrix

# %%
data=pd.Series(raw_data)

# %%
data
# Out:
# 0     VanDyke SecureCRT and SecureFX 2021 Free Down...
# dtype: object

# %%
data_processed= data.apply(lambda x: re.sub(r'[^a-zA-Z/s]+',' ',x).lower())
data_processed
# Out:
# 0     vandyke securecrt and securefx free download ...
# dtype: object

# %%
stop_words= stopwords.words('english')

# %%
from nltk import word_tokenize

# %%
data_final = data_processed.apply(lambda x:' '.join([word for word in word_tokenize(x) if word not in stop_words and len(word)>2]))

# %%
data_final
# Out:
# 0    vandyke securecrt securefx free download vandy...
# dtype: object

# %%
words_list = []
for sentence in data_final:
    words_list.extend(nltk.word_tokenize(sentence))
freq_dist = nltk.FreqDist(words_list)
freq_dist.most_common()
# Out:
# [('free', 39),
#  ('securefx', 29),
#  ('vandyke', 27),
#  ('securecrt', 25),
#  ('file', 24),
#  ('download', 22),
#  ('secure', 20),
#  ('network', 20),
#  ('transfer', 16),
#  ('transfers', 16),
#  ('full', 15),
#  ('offers', 14),
#  ('remote', 12),
#  ('data', 12),
#  ('range', 12),
#  ('setup', 11),
#  ('provides', 10),
#  ('features', 10),
#  ('ensure', 10),
#  ('system', 10),
#  ('high', 8),
#  ('application', 8),
#  ('administrators', 8),
#  ('access', 8),
#  ('reliable', 8),
#  ('robust', 8),
#  ('ssh', 8),
#  ('advanced', 8),
#  ('allowing', 8),
#  ('supports', 8),
#  ('wide', 8),
#  ('protocols', 8),
#  ('support', 8),
#  ('also', 8),
#  ('options', 8),
#  ('strong', 8),
#  ('encryption', 8),
#  ('server', 8),
#  ('authentication', 8),
#  ('bit', 8),
#  ('offline', 6),
#  ('installer', 6),
#  ('standalone', 6),
#  ('program', 6),
#  ('thus', 6),
#  ('software', 6),
#  ('pro', 6),
#  ('windows', 6),
#  ('build', 5),
#  ('speed', 4),
#  ('tunneling', 4),
#  ('across', 4),
#  ('tool', 4),
#  ('security', 4),
#  ('extensive', 4),
#  ('session', 4),
#  ('management', 4),
#  ('scripting', 4),
#  ('capabilities', 4),
#  ('raise', 4),
#  ('productivity', 4),
#  ('next', 4),
#  ('level', 4),
#  ('site', 4),
#  ('synchronization', 4),
#  ('automation', 4),
#  ('help', 4),
#  ('web', 4),
#  ('designers', 4),
#  ('streamline', 4),
#  ('everyday', 4),
#  ('tasks', 4),
#  ('popular', 4),
#  ('sftp', 4),
#  ('ftp/tls', 4),
#  ('scp', 4),
#  ('providing', 4),
#  ('maximum', 4),
#  ('flexibility', 4),
#  ('connecting', 4),
#  ('servers', 4),
#  ('easy', 4),
#  ('use', 4),
#  ('explorer', 4),
#  ('like', 4),
#  ('interface', 4),
#  ('drag', 4),
#  ('drop', 4),
#  ('desktop', 4),
#  ('applications', 4),
#  ('useful', 4),
#  ('responsible', 4),
#  ('configuring', 4),
#  ('general', 4),
#  ('uses', 4),
#  ('variety', 4),
#  ('algorithms', 4),
#  ('aes', 4),
#  ('twofish', 4),
#  ('blowfish', 4),
#  ('des', 4),
#  ('empowers', 4),
#  ('automate', 4),
#  ('synchronize', 4),
#  ('local', 4),
#  ('files', 4),
#  ('perform', 4),
#  ('facilitates', 4),
#  ('encrypted', 4),
#  ('logons', 4),
#  ('flexible', 4),
#  ('integrity', 4),
#  ('message', 4),
#  ('sent', 4),
#  ('multiple', 4),
#  ('platforms', 4),
#  ('apply', 4),
#  ('mechanism', 4),
#  ('shell', 4),
#  ('protocol', 4),
#  ('administration', 4),
#  ('end', 4),
#  ('user', 4),
#  ('relentless', 4),
#  ('automatically', 4),
#  ('reconnect', 4),
#  ('resume', 4),
#  ('connections', 4),
#  ('broken', 4),
#  ('start', 4),
#  ('name', 4),
#  ('operating', 4),
#  ('sitemidas', 4),
#  ('meshfree', 4),
#  ('downloadsonokinetic', 4),
#  ('kemence', 4),
#  ('kontakt', 4),
#  ('downloadcomsol', 4),
#  ('multiphysics', 4),
#  ('downloadveritas', 4),
#  ('recovery', 4),
#  ('downloadgeometric', 4),
#  ('glovius', 4),
#  ('downloadwinrar', 4),
#  ('final', 4),
#  ('overviewvandyke', 2),
#  ('frostwire', 2),
#  ('sharing', 2),
#  ('excellent', 2),
#  ('filezilla', 2),
#  ('featuresbelow', 2),
#  ('noticeable', 2),
#  ('experience', 2),
#  ('got', 2),
#  ('technical', 2),
#  ('detailsprior', 2),
#  ('availability', 2),
#  ('listed', 2),
#  ('specificationssoftware', 2),
#  ('rarsetup', 2),
#  ('size', 2),
#  ('mbsetup', 2),
#  ('type', 2),
#  ('setupcompatibility', 2),
#  ('mechanical', 2),
#  ('latest', 2),
#  ('version', 2),
#  ('release', 2),
#  ('added', 2),
#  ('apr', 2),
#  ('developers', 2),
#  ('securecrtsystem', 2),
#  ('requirements', 2),
#  ('xp/vista/', 2),
#  ('ram', 2),
#  ('mbhard', 2),
#  ('disk', 2),
#  ('mbprocessor', 2),
#  ('intel', 2),
#  ('pentium', 2),
#  ('higher', 2),
#  ('processorvandyke', 2),
#  ('downloadclick', 2),
#  ('link', 2),
#  ('would', 2),
#  ('compatible', 2),
#  ('installing', 2),
#  ('must', 2),
#  ('watch', 2),
#  ('installation', 2),
#  ('guide', 2),
#  ('video', 2),
#  ('password', 2),
#  ('downloadthis', 2),
#  ('post', 2),
#  ('last', 2),
#  ('updated', 2),
#  ('april', 2)]

# %%
words_list
# Out:
# ['vandyke',
#  'securecrt',
#  'securefx',
#  'free',
#  'download',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'free',
#  'download',
#  'full',
#  'offline',
#  'installer',
#  'standalone',
#  'setup',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'overviewvandyke',
#  'securefx',
#  'high',
#  'speed',
#  'secure',
#  'file',
#  'transfer',
#  'application',
#  'provides',
#  'network',
#  'administrators',
#  'secure',
#  'remote',
#  'access',
#  'file',
#  'transfer',
#  'data',
#  'tunneling',
#  'across',
#  'network',
#  'reliable',
#  'tool',
#  'offers',
#  'robust',
#  'security',
#  'ssh',
#  'extensive',
#  'session',
#  'management',
#  'advanced',
#  'scripting',
#  'capabilities',
#  'allowing',
#  'raise',
#  'productivity',
#  'next',
#  'high',
#  'level',
#  'program',
#  'offers',
#  'advanced',
#  'site',
#  'synchronization',
#  'automation',
#  'features',
#  'help',
#  'web',
#  'designers',
#  'network',
#  'administrators',
#  'streamline',
#  'everyday',
#  'tasks',
#  'program',
#  'supports',
#  'wide',
#  'range',
#  'popular',
#  'protocols',
#  'ssh',
#  'sftp',
#  'ftp/tls',
#  'scp',
#  'thus',
#  'providing',
#  'maximum',
#  'flexibility',
#  'connecting',
#  'range',
#  'remote',
#  'servers',
#  'easy',
#  'use',
#  'explorer',
#  'like',
#  'interface',
#  'full',
#  'support',
#  'drag',
#  'drop',
#  'file',
#  'transfers',
#  'desktop',
#  'applications',
#  'also',
#  'download',
#  'frostwire',
#  'free',
#  'download',
#  'file',
#  'sharing',
#  'application',
#  'vandyke',
#  'securefx',
#  'excellent',
#  'application',
#  'offers',
#  'wide',
#  'range',
#  'useful',
#  'features',
#  'options',
#  'responsible',
#  'configuring',
#  'general',
#  'software',
#  'data',
#  'transfer',
#  'protocols',
#  'uses',
#  'variety',
#  'reliable',
#  'robust',
#  'algorithms',
#  'aes',
#  'twofish',
#  'blowfish',
#  'des',
#  'ensure',
#  'strong',
#  'data',
#  'encryption',
#  'thus',
#  'empowers',
#  'automate',
#  'secure',
#  'file',
#  'transfers',
#  'synchronize',
#  'local',
#  'remote',
#  'files',
#  'perform',
#  'server',
#  'server',
#  'transfers',
#  'also',
#  'facilitates',
#  'encrypted',
#  'logons',
#  'provides',
#  'flexible',
#  'authentication',
#  'options',
#  'ensure',
#  'integrity',
#  'message',
#  'sent',
#  'network',
#  'program',
#  'offers',
#  'support',
#  'multiple',
#  'platforms',
#  'allowing',
#  'apply',
#  'strong',
#  'encryption',
#  'authentication',
#  'mechanism',
#  'secure',
#  'shell',
#  'protocol',
#  'secure',
#  'network',
#  'administration',
#  'end',
#  'user',
#  'access',
#  'also',
#  'supports',
#  'relentless',
#  'file',
#  'transfers',
#  'automatically',
#  'reconnect',
#  'resume',
#  'transfer',
#  'connections',
#  'broken',
#  'also',
#  'download',
#  'filezilla',
#  'pro',
#  'free',
#  'download',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'featuresbelow',
#  'noticeable',
#  'features',
#  'experience',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'free',
#  'download',
#  'high',
#  'speed',
#  'secure',
#  'file',
#  'transfer',
#  'application',
#  'provides',
#  'network',
#  'administrators',
#  'secure',
#  'remote',
#  'access',
#  'file',
#  'transfer',
#  'data',
#  'tunneling',
#  'across',
#  'network',
#  'reliable',
#  'tool',
#  'offers',
#  'robust',
#  'security',
#  'ssh',
#  'extensive',
#  'session',
#  'management',
#  'advanced',
#  'scripting',
#  'capabilities',
#  'allowing',
#  'raise',
#  'productivity',
#  'next',
#  'high',
#  'level',
#  'offers',
#  'advanced',
#  'site',
#  'synchronization',
#  'automation',
#  'features',
#  'help',
#  'web',
#  'designers',
#  'network',
#  'administrators',
#  'streamline',
#  'everyday',
#  'tasks',
#  'supports',
#  'wide',
#  'range',
#  'popular',
#  'protocols',
#  'ssh',
#  'sftp',
#  'ftp/tls',
#  'scp',
#  'thus',
#  'providing',
#  'maximum',
#  'flexibility',
#  'connecting',
#  'range',
#  'remote',
#  'servers',
#  'got',
#  'easy',
#  'use',
#  'explorer',
#  'like',
#  'interface',
#  'full',
#  'support',
#  'drag',
#  'drop',
#  'file',
#  'transfers',
#  'desktop',
#  'applications',
#  'provides',
#  'wide',
#  'range',
#  'useful',
#  'features',
#  'options',
#  'responsible',
#  'configuring',
#  'general',
#  'software',
#  'data',
#  'transfer',
#  'protocols',
#  'uses',
#  'variety',
#  'reliable',
#  'robust',
#  'algorithms',
#  'aes',
#  'twofish',
#  'blowfish',
#  'des',
#  'ensure',
#  'strong',
#  'data',
#  'encryption',
#  'empowers',
#  'automate',
#  'secure',
#  'file',
#  'transfers',
#  'synchronize',
#  'local',
#  'remote',
#  'files',
#  'perform',
#  'server',
#  'server',
#  'transfers',
#  'facilitates',
#  'encrypted',
#  'logons',
#  'provides',
#  'flexible',
#  'authentication',
#  'options',
#  'ensure',
#  'integrity',
#  'message',
#  'sent',
#  'network',
#  'offers',
#  'support',
#  'multiple',
#  'platforms',
#  'allowing',
#  'apply',
#  'strong',
#  'encryption',
#  'authentication',
#  'mechanism',
#  'secure',
#  'shell',
#  'protocol',
#  'secure',
#  'network',
#  'administration',
#  'end',
#  'user',
#  'access',
#  'supports',
#  'relentless',
#  'file',
#  'transfers',
#  'automatically',
#  'reconnect',
#  'resume',
#  'transfer',
#  'connections',
#  'broken',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'technical',
#  'setup',
#  'detailsprior',
#  'start',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'free',
#  'download',
#  'ensure',
#  'availability',
#  'listed',
#  'system',
#  'specificationssoftware',
#  'full',
#  'name',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'setup',
#  'file',
#  'name',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'build',
#  'rarsetup',
#  'size',
#  'mbsetup',
#  'type',
#  'offline',
#  'installer',
#  'full',
#  'standalone',
#  'setupcompatibility',
#  'mechanical',
#  'bit',
#  'bit',
#  'latest',
#  'version',
#  'release',
#  'added',
#  'apr',
#  'developers',
#  'vandyke',
#  'securecrtsystem',
#  'requirements',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'operating',
#  'system',
#  'windows',
#  'xp/vista/',
#  'ram',
#  'mbhard',
#  'disk',
#  'mbprocessor',
#  'intel',
#  'pentium',
#  'higher',
#  'processorvandyke',
#  'securecrt',
#  'securefx',
#  'free',
#  'downloadclick',
#  'link',
#  'start',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'free',
#  'download',
#  'full',
#  'offline',
#  'installer',
#  'standalone',
#  'setup',
#  'windows',
#  'operating',
#  'system',
#  'would',
#  'compatible',
#  'bit',
#  'bit',
#  'windows',
#  'installing',
#  'software',
#  'must',
#  'watch',
#  'installation',
#  'guide',
#  'video',
#  'download',
#  'full',
#  'setup',
#  'build',
#  'password',
#  'sitemidas',
#  'meshfree',
#  'free',
#  'downloadsonokinetic',
#  'kemence',
#  'kontakt',
#  'free',
#  'downloadcomsol',
#  'multiphysics',
#  'free',
#  'downloadveritas',
#  'system',
#  'recovery',
#  'free',
#  'downloadgeometric',
#  'glovius',
#  'pro',
#  'free',
#  'downloadwinrar',
#  'final',
#  'free',
#  'downloadthis',
#  'post',
#  'last',
#  'updated',
#  'april',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'free',
#  'download',
#  'full',
#  'offline',
#  'installer',
#  'standalone',
#  'setup',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'overviewvandyke',
#  'securefx',
#  'high',
#  'speed',
#  'secure',
#  'file',
#  'transfer',
#  'application',
#  'provides',
#  'network',
#  'administrators',
#  'secure',
#  'remote',
#  'access',
#  'file',
#  'transfer',
#  'data',
#  'tunneling',
#  'across',
#  'network',
#  'reliable',
#  'tool',
#  'offers',
#  'robust',
#  'security',
#  'ssh',
#  'extensive',
#  'session',
#  'management',
#  'advanced',
#  'scripting',
#  'capabilities',
#  'allowing',
#  'raise',
#  'productivity',
#  'next',
#  'high',
#  'level',
#  'program',
#  'offers',
#  'advanced',
#  'site',
#  'synchronization',
#  'automation',
#  'features',
#  'help',
#  'web',
#  'designers',
#  'network',
#  'administrators',
#  'streamline',
#  'everyday',
#  'tasks',
#  'program',
#  'supports',
#  'wide',
#  'range',
#  'popular',
#  'protocols',
#  'ssh',
#  'sftp',
#  'ftp/tls',
#  'scp',
#  'thus',
#  'providing',
#  'maximum',
#  'flexibility',
#  'connecting',
#  'range',
#  'remote',
#  'servers',
#  'easy',
#  'use',
#  'explorer',
#  'like',
#  'interface',
#  'full',
#  'support',
#  'drag',
#  'drop',
#  'file',
#  'transfers',
#  'desktop',
#  'applications',
#  'also',
#  'download',
#  'frostwire',
#  'free',
#  'download',
#  'file',
#  'sharing',
#  'application',
#  'vandyke',
#  'securefx',
#  'excellent',
#  'application',
#  'offers',
#  'wide',
#  'range',
#  'useful',
#  'features',
#  'options',
#  'responsible',
#  'configuring',
#  'general',
#  'software',
#  'data',
#  'transfer',
#  'protocols',
#  'uses',
#  'variety',
#  'reliable',
#  'robust',
#  'algorithms',
#  'aes',
#  'twofish',
#  'blowfish',
#  'des',
#  'ensure',
#  'strong',
#  'data',
#  'encryption',
#  'thus',
#  'empowers',
#  'automate',
#  'secure',
#  'file',
#  'transfers',
#  'synchronize',
#  'local',
#  'remote',
#  'files',
#  'perform',
#  'server',
#  'server',
#  'transfers',
#  'also',
#  'facilitates',
#  'encrypted',
#  'logons',
#  'provides',
#  'flexible',
#  'authentication',
#  'options',
#  'ensure',
#  'integrity',
#  'message',
#  'sent',
#  'network',
#  'program',
#  'offers',
#  'support',
#  'multiple',
#  'platforms',
#  'allowing',
#  'apply',
#  'strong',
#  'encryption',
#  'authentication',
#  'mechanism',
#  'secure',
#  'shell',
#  'protocol',
#  'secure',
#  'network',
#  'administration',
#  'end',
#  'user',
#  'access',
#  'also',
#  'supports',
#  'relentless',
#  'file',
#  'transfers',
#  'automatically',
#  'reconnect',
#  'resume',
#  'transfer',
#  'connections',
#  'broken',
#  'also',
#  'download',
#  'filezilla',
#  'pro',
#  'free',
#  'download',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'featuresbelow',
#  'noticeable',
#  'features',
#  'experience',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'free',
#  'download',
#  'high',
#  'speed',
#  'secure',
#  'file',
#  'transfer',
#  'application',
#  'provides',
#  'network',
#  'administrators',
#  'secure',
#  'remote',
#  'access',
#  'file',
#  'transfer',
#  'data',
#  'tunneling',
#  'across',
#  'network',
#  'reliable',
#  'tool',
#  'offers',
#  'robust',
#  'security',
#  'ssh',
#  'extensive',
#  'session',
#  'management',
#  'advanced',
#  'scripting',
#  'capabilities',
#  'allowing',
#  'raise',
#  'productivity',
#  'next',
#  'high',
#  'level',
#  'offers',
#  'advanced',
#  'site',
#  'synchronization',
#  'automation',
#  'features',
#  'help',
#  'web',
#  'designers',
#  'network',
#  'administrators',
#  'streamline',
#  'everyday',
#  'tasks',
#  'supports',
#  'wide',
#  'range',
#  'popular',
#  'protocols',
#  'ssh',
#  'sftp',
#  'ftp/tls',
#  'scp',
#  'thus',
#  'providing',
#  'maximum',
#  'flexibility',
#  'connecting',
#  'range',
#  'remote',
#  'servers',
#  'got',
#  'easy',
#  'use',
#  'explorer',
#  'like',
#  'interface',
#  'full',
#  'support',
#  'drag',
#  'drop',
#  'file',
#  'transfers',
#  'desktop',
#  'applications',
#  'provides',
#  'wide',
#  'range',
#  'useful',
#  'features',
#  'options',
#  'responsible',
#  'configuring',
#  'general',
#  'software',
#  'data',
#  'transfer',
#  'protocols',
#  'uses',
#  'variety',
#  'reliable',
#  'robust',
#  'algorithms',
#  'aes',
#  'twofish',
#  'blowfish',
#  'des',
#  'ensure',
#  'strong',
#  'data',
#  'encryption',
#  'empowers',
#  'automate',
#  'secure',
#  'file',
#  'transfers',
#  'synchronize',
#  'local',
#  'remote',
#  'files',
#  'perform',
#  'server',
#  'server',
#  'transfers',
#  'facilitates',
#  'encrypted',
#  'logons',
#  'provides',
#  'flexible',
#  'authentication',
#  'options',
#  'ensure',
#  'integrity',
#  'message',
#  'sent',
#  'network',
#  'offers',
#  'support',
#  'multiple',
#  'platforms',
#  'allowing',
#  'apply',
#  'strong',
#  'encryption',
#  'authentication',
#  'mechanism',
#  'secure',
#  'shell',
#  'protocol',
#  'secure',
#  'network',
#  'administration',
#  'end',
#  'user',
#  'access',
#  'supports',
#  'relentless',
#  'file',
#  'transfers',
#  'automatically',
#  'reconnect',
#  'resume',
#  'transfer',
#  'connections',
#  'broken',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'technical',
#  'setup',
#  'detailsprior',
#  'start',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'free',
#  'download',
#  'ensure',
#  'availability',
#  'listed',
#  'system',
#  'specificationssoftware',
#  'full',
#  'name',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'setup',
#  'file',
#  'name',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'build',
#  'rarsetup',
#  'size',
#  'mbsetup',
#  'type',
#  'offline',
#  'installer',
#  'full',
#  'standalone',
#  'setupcompatibility',
#  'mechanical',
#  'bit',
#  'bit',
#  'latest',
#  'version',
#  'release',
#  'added',
#  'apr',
#  'developers',
#  'vandyke',
#  'securecrtsystem',
#  'requirements',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'operating',
#  'system',
#  'windows',
#  'xp/vista/',
#  'ram',
#  'mbhard',
#  'disk',
#  'mbprocessor',
#  'intel',
#  'pentium',
#  'higher',
#  'processorvandyke',
#  'securecrt',
#  'securefx',
#  'free',
#  'downloadclick',
#  'link',
#  'start',
#  'vandyke',
#  'securecrt',
#  'securefx',
#  'free',
#  'download',
#  'full',
#  'offline',
#  'installer',
#  'standalone',
#  'setup',
#  'windows',
#  'operating',
#  'system',
#  'would',
#  'compatible',
#  'bit',
#  'bit',
#  'windows',
#  'installing',
#  'software',
#  'must',
#  'watch',
#  'installation',
#  'guide',
#  'video',
#  'download',
#  'full',
#  'setup',
#  'build',
#  'password',
#  'sitemidas',
#  'meshfree',
#  'free',
#  'downloadsonokinetic',
#  'kemence',
#  'kontakt',
#  'free',
#  'downloadcomsol',
#  'multiphysics',
#  'free',
#  'downloadveritas',
#  'system',
#  'recovery',
#  'free',
#  'downloadgeometric',
#  'glovius',
#  'pro',
#  ...]

# %%
from wordcloud import WordCloud
import wordcloud

wcloud_fig = WordCloud( stopwords = set(wordcloud.STOPWORDS), colormap = 'viridis', width = 300 , height = 200).generate_from_frequencies(freq_dist)

#plotting the wordcloud
plt.figure(figsize=(10,7), frameon=True)

plt.imshow(wcloud_fig, interpolation = 'bilinear')
plt.show()

# %%
import gensim
from gensim.models import Phrases
from gensim.models.phrases import Phraser
from gensim import models

# %%
words_sent = [x.split() for x in data_final]
words_sent
bigram= Phrases(words_sent, min_count=5, threshold=100)
trigram= Phrases(bigram[words_sent], threshold=100)

bigram_phraser= Phraser(bigram)
trigram_phraser= Phraser(trigram)

#bag of words for creating bigram and trigram

bow=[trigram_phraser[bigram_phraser[word]] for word in words_sent]

# %%
bow[0:1]
# Out:
# [['vandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'download',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'download',
#   'full',
#   'offline',
#   'installer',
#   'standalone',
#   'setup',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'overviewvandyke',
#   'securefx',
#   'high',
#   'speed',
#   'secure',
#   'file',
#   'transfer',
#   'application',
#   'provides',
#   'network',
#   'administrators',
#   'secure',
#   'remote',
#   'access',
#   'file',
#   'transfer',
#   'data',
#   'tunneling',
#   'across',
#   'network',
#   'reliable',
#   'tool',
#   'offers',
#   'robust',
#   'security',
#   'ssh',
#   'extensive',
#   'session',
#   'management',
#   'advanced',
#   'scripting',
#   'capabilities',
#   'allowing',
#   'raise',
#   'productivity',
#   'next',
#   'high',
#   'level',
#   'program',
#   'offers',
#   'advanced',
#   'site',
#   'synchronization',
#   'automation',
#   'features',
#   'help',
#   'web',
#   'designers',
#   'network',
#   'administrators',
#   'streamline',
#   'everyday',
#   'tasks',
#   'program',
#   'supports',
#   'wide',
#   'range',
#   'popular',
#   'protocols',
#   'ssh',
#   'sftp',
#   'ftp/tls',
#   'scp',
#   'thus',
#   'providing',
#   'maximum',
#   'flexibility',
#   'connecting',
#   'range',
#   'remote',
#   'servers',
#   'easy',
#   'use',
#   'explorer',
#   'like',
#   'interface',
#   'full',
#   'support',
#   'drag',
#   'drop',
#   'file',
#   'transfers',
#   'desktop',
#   'applications',
#   'also',
#   'download',
#   'frostwire',
#   'free',
#   'download',
#   'file',
#   'sharing',
#   'application',
#   'vandyke',
#   'securefx',
#   'excellent',
#   'application',
#   'offers',
#   'wide',
#   'range',
#   'useful',
#   'features',
#   'options',
#   'responsible',
#   'configuring',
#   'general',
#   'software',
#   'data',
#   'transfer',
#   'protocols',
#   'uses',
#   'variety',
#   'reliable',
#   'robust',
#   'algorithms',
#   'aes',
#   'twofish',
#   'blowfish',
#   'des',
#   'ensure',
#   'strong',
#   'data',
#   'encryption',
#   'thus',
#   'empowers',
#   'automate',
#   'secure',
#   'file',
#   'transfers',
#   'synchronize',
#   'local',
#   'remote',
#   'files',
#   'perform',
#   'server',
#   'server',
#   'transfers',
#   'also',
#   'facilitates',
#   'encrypted',
#   'logons',
#   'provides',
#   'flexible',
#   'authentication',
#   'options',
#   'ensure',
#   'integrity',
#   'message',
#   'sent',
#   'network',
#   'program',
#   'offers',
#   'support',
#   'multiple',
#   'platforms',
#   'allowing',
#   'apply',
#   'strong',
#   'encryption',
#   'authentication',
#   'mechanism',
#   'secure',
#   'shell',
#   'protocol',
#   'secure',
#   'network',
#   'administration',
#   'end',
#   'user',
#   'access',
#   'also',
#   'supports',
#   'relentless',
#   'file',
#   'transfers',
#   'automatically',
#   'reconnect',
#   'resume',
#   'transfer',
#   'connections',
#   'broken',
#   'also',
#   'download',
#   'filezilla',
#   'pro',
#   'free',
#   'download',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'featuresbelow',
#   'noticeable',
#   'features',
#   'experience',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'download',
#   'high',
#   'speed',
#   'secure',
#   'file',
#   'transfer',
#   'application',
#   'provides',
#   'network',
#   'administrators',
#   'secure',
#   'remote',
#   'access',
#   'file',
#   'transfer',
#   'data',
#   'tunneling',
#   'across',
#   'network',
#   'reliable',
#   'tool',
#   'offers',
#   'robust',
#   'security',
#   'ssh',
#   'extensive',
#   'session',
#   'management',
#   'advanced',
#   'scripting',
#   'capabilities',
#   'allowing',
#   'raise',
#   'productivity',
#   'next',
#   'high',
#   'level',
#   'offers',
#   'advanced',
#   'site',
#   'synchronization',
#   'automation',
#   'features',
#   'help',
#   'web',
#   'designers',
#   'network',
#   'administrators',
#   'streamline',
#   'everyday',
#   'tasks',
#   'supports',
#   'wide',
#   'range',
#   'popular',
#   'protocols',
#   'ssh',
#   'sftp',
#   'ftp/tls',
#   'scp',
#   'thus',
#   'providing',
#   'maximum',
#   'flexibility',
#   'connecting',
#   'range',
#   'remote',
#   'servers',
#   'got',
#   'easy',
#   'use',
#   'explorer',
#   'like',
#   'interface',
#   'full',
#   'support',
#   'drag',
#   'drop',
#   'file',
#   'transfers',
#   'desktop',
#   'applications',
#   'provides',
#   'wide',
#   'range',
#   'useful',
#   'features',
#   'options',
#   'responsible',
#   'configuring',
#   'general',
#   'software',
#   'data',
#   'transfer',
#   'protocols',
#   'uses',
#   'variety',
#   'reliable',
#   'robust',
#   'algorithms',
#   'aes',
#   'twofish',
#   'blowfish',
#   'des',
#   'ensure',
#   'strong',
#   'data',
#   'encryption',
#   'empowers',
#   'automate',
#   'secure',
#   'file',
#   'transfers',
#   'synchronize',
#   'local',
#   'remote',
#   'files',
#   'perform',
#   'server',
#   'server',
#   'transfers',
#   'facilitates',
#   'encrypted',
#   'logons',
#   'provides',
#   'flexible',
#   'authentication',
#   'options',
#   'ensure',
#   'integrity',
#   'message',
#   'sent',
#   'network',
#   'offers',
#   'support',
#   'multiple',
#   'platforms',
#   'allowing',
#   'apply',
#   'strong',
#   'encryption',
#   'authentication',
#   'mechanism',
#   'secure',
#   'shell',
#   'protocol',
#   'secure',
#   'network',
#   'administration',
#   'end',
#   'user',
#   'access',
#   'supports',
#   'relentless',
#   'file',
#   'transfers',
#   'automatically',
#   'reconnect',
#   'resume',
#   'transfer',
#   'connections',
#   'broken',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'technical',
#   'setup',
#   'detailsprior',
#   'start',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'download',
#   'ensure',
#   'availability',
#   'listed',
#   'system',
#   'specificationssoftware',
#   'full',
#   'name',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'setup',
#   'file',
#   'name',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'build',
#   'rarsetup',
#   'size',
#   'mbsetup',
#   'type',
#   'offline',
#   'installer',
#   'full',
#   'standalone',
#   'setupcompatibility',
#   'mechanical',
#   'bit',
#   'bit',
#   'latest',
#   'version',
#   'release',
#   'added',
#   'apr',
#   'developers',
#   'vandyke',
#   'securecrtsystem',
#   'requirements',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'operating',
#   'system',
#   'windows',
#   'xp/vista/',
#   'ram',
#   'mbhard',
#   'disk',
#   'mbprocessor',
#   'intel',
#   'pentium',
#   'higher',
#   'processorvandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'downloadclick',
#   'link',
#   'start',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'download',
#   'full',
#   'offline',
#   'installer',
#   'standalone',
#   'setup',
#   'windows',
#   'operating',
#   'system',
#   'would',
#   'compatible',
#   'bit',
#   'bit',
#   'windows',
#   'installing',
#   'software',
#   'must',
#   'watch',
#   'installation',
#   'guide',
#   'video',
#   'download',
#   'full',
#   'setup',
#   'build',
#   'password',
#   'sitemidas',
#   'meshfree',
#   'free',
#   'downloadsonokinetic',
#   'kemence',
#   'kontakt',
#   'free',
#   'downloadcomsol',
#   'multiphysics',
#   'free',
#   'downloadveritas',
#   'system',
#   'recovery',
#   'free',
#   'downloadgeometric',
#   'glovius',
#   'pro',
#   'free',
#   'downloadwinrar',
#   'final',
#   'free',
#   'downloadthis',
#   'post',
#   'last',
#   'updated',
#   'april',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'download',
#   'full',
#   'offline',
#   'installer',
#   'standalone',
#   'setup',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'overviewvandyke',
#   'securefx',
#   'high',
#   'speed',
#   'secure',
#   'file',
#   'transfer',
#   'application',
#   'provides',
#   'network',
#   'administrators',
#   'secure',
#   'remote',
#   'access',
#   'file',
#   'transfer',
#   'data',
#   'tunneling',
#   'across',
#   'network',
#   'reliable',
#   'tool',
#   'offers',
#   'robust',
#   'security',
#   'ssh',
#   'extensive',
#   'session',
#   'management',
#   'advanced',
#   'scripting',
#   'capabilities',
#   'allowing',
#   'raise',
#   'productivity',
#   'next',
#   'high',
#   'level',
#   'program',
#   'offers',
#   'advanced',
#   'site',
#   'synchronization',
#   'automation',
#   'features',
#   'help',
#   'web',
#   'designers',
#   'network',
#   'administrators',
#   'streamline',
#   'everyday',
#   'tasks',
#   'program',
#   'supports',
#   'wide',
#   'range',
#   'popular',
#   'protocols',
#   'ssh',
#   'sftp',
#   'ftp/tls',
#   'scp',
#   'thus',
#   'providing',
#   'maximum',
#   'flexibility',
#   'connecting',
#   'range',
#   'remote',
#   'servers',
#   'easy',
#   'use',
#   'explorer',
#   'like',
#   'interface',
#   'full',
#   'support',
#   'drag',
#   'drop',
#   'file',
#   'transfers',
#   'desktop',
#   'applications',
#   'also',
#   'download',
#   'frostwire',
#   'free',
#   'download',
#   'file',
#   'sharing',
#   'application',
#   'vandyke',
#   'securefx',
#   'excellent',
#   'application',
#   'offers',
#   'wide',
#   'range',
#   'useful',
#   'features',
#   'options',
#   'responsible',
#   'configuring',
#   'general',
#   'software',
#   'data',
#   'transfer',
#   'protocols',
#   'uses',
#   'variety',
#   'reliable',
#   'robust',
#   'algorithms',
#   'aes',
#   'twofish',
#   'blowfish',
#   'des',
#   'ensure',
#   'strong',
#   'data',
#   'encryption',
#   'thus',
#   'empowers',
#   'automate',
#   'secure',
#   'file',
#   'transfers',
#   'synchronize',
#   'local',
#   'remote',
#   'files',
#   'perform',
#   'server',
#   'server',
#   'transfers',
#   'also',
#   'facilitates',
#   'encrypted',
#   'logons',
#   'provides',
#   'flexible',
#   'authentication',
#   'options',
#   'ensure',
#   'integrity',
#   'message',
#   'sent',
#   'network',
#   'program',
#   'offers',
#   'support',
#   'multiple',
#   'platforms',
#   'allowing',
#   'apply',
#   'strong',
#   'encryption',
#   'authentication',
#   'mechanism',
#   'secure',
#   'shell',
#   'protocol',
#   'secure',
#   'network',
#   'administration',
#   'end',
#   'user',
#   'access',
#   'also',
#   'supports',
#   'relentless',
#   'file',
#   'transfers',
#   'automatically',
#   'reconnect',
#   'resume',
#   'transfer',
#   'connections',
#   'broken',
#   'also',
#   'download',
#   'filezilla',
#   'pro',
#   'free',
#   'download',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'featuresbelow',
#   'noticeable',
#   'features',
#   'experience',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'download',
#   'high',
#   'speed',
#   'secure',
#   'file',
#   'transfer',
#   'application',
#   'provides',
#   'network',
#   'administrators',
#   'secure',
#   'remote',
#   'access',
#   'file',
#   'transfer',
#   'data',
#   'tunneling',
#   'across',
#   'network',
#   'reliable',
#   'tool',
#   'offers',
#   'robust',
#   'security',
#   'ssh',
#   'extensive',
#   'session',
#   'management',
#   'advanced',
#   'scripting',
#   'capabilities',
#   'allowing',
#   'raise',
#   'productivity',
#   'next',
#   'high',
#   'level',
#   'offers',
#   'advanced',
#   'site',
#   'synchronization',
#   'automation',
#   'features',
#   'help',
#   'web',
#   'designers',
#   'network',
#   'administrators',
#   'streamline',
#   'everyday',
#   'tasks',
#   'supports',
#   'wide',
#   'range',
#   'popular',
#   'protocols',
#   'ssh',
#   'sftp',
#   'ftp/tls',
#   'scp',
#   'thus',
#   'providing',
#   'maximum',
#   'flexibility',
#   'connecting',
#   'range',
#   'remote',
#   'servers',
#   'got',
#   'easy',
#   'use',
#   'explorer',
#   'like',
#   'interface',
#   'full',
#   'support',
#   'drag',
#   'drop',
#   'file',
#   'transfers',
#   'desktop',
#   'applications',
#   'provides',
#   'wide',
#   'range',
#   'useful',
#   'features',
#   'options',
#   'responsible',
#   'configuring',
#   'general',
#   'software',
#   'data',
#   'transfer',
#   'protocols',
#   'uses',
#   'variety',
#   'reliable',
#   'robust',
#   'algorithms',
#   'aes',
#   'twofish',
#   'blowfish',
#   'des',
#   'ensure',
#   'strong',
#   'data',
#   'encryption',
#   'empowers',
#   'automate',
#   'secure',
#   'file',
#   'transfers',
#   'synchronize',
#   'local',
#   'remote',
#   'files',
#   'perform',
#   'server',
#   'server',
#   'transfers',
#   'facilitates',
#   'encrypted',
#   'logons',
#   'provides',
#   'flexible',
#   'authentication',
#   'options',
#   'ensure',
#   'integrity',
#   'message',
#   'sent',
#   'network',
#   'offers',
#   'support',
#   'multiple',
#   'platforms',
#   'allowing',
#   'apply',
#   'strong',
#   'encryption',
#   'authentication',
#   'mechanism',
#   'secure',
#   'shell',
#   'protocol',
#   'secure',
#   'network',
#   'administration',
#   'end',
#   'user',
#   'access',
#   'supports',
#   'relentless',
#   'file',
#   'transfers',
#   'automatically',
#   'reconnect',
#   'resume',
#   'transfer',
#   'connections',
#   'broken',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'technical',
#   'setup',
#   'detailsprior',
#   'start',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'download',
#   'ensure',
#   'availability',
#   'listed',
#   'system',
#   'specificationssoftware',
#   'full',
#   'name',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'setup',
#   'file',
#   'name',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'build',
#   'rarsetup',
#   'size',
#   'mbsetup',
#   'type',
#   'offline',
#   'installer',
#   'full',
#   'standalone',
#   'setupcompatibility',
#   'mechanical',
#   'bit',
#   'bit',
#   'latest',
#   'version',
#   'release',
#   'added',
#   'apr',
#   'developers',
#   'vandyke',
#   'securecrtsystem',
#   'requirements',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'operating',
#   'system',
#   'windows',
#   'xp/vista/',
#   'ram',
#   'mbhard',
#   'disk',
#   'mbprocessor',
#   'intel',
#   'pentium',
#   'higher',
#   'processorvandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'downloadclick',
#   'link',
#   'start',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'download',
#   'full',
#   'offline',
#   'installer',
#   'standalone',
#   'setup',
#   'windows',
#   'operating',
#   'system',
#   'would',
#   'compatible',
#   'bit',
#   'bit',
#   'windows',
#   'installing',
#   'software',
#   'must',
#   'watch',
#   'installation',
#   'guide',
#   'video',
#   'download',
#   'full',
#   'setup',
#   'build',
#   'password',
#   'sitemidas',
#   'meshfree',
#   'free',
#   'downloadsonokinetic',
#   'kemence',
#   'kontakt',
#   'free',
#   'downloadcomsol',
#   'multiphysics',
#   'free',
#   'downloadveritas',
#   'system',
#   'recovery',
#   'free',
#   'downloadgeometric',
#   'glovius',
#   'pro',
#   ...]]

# %%
import spacy
nlp= spacy.load('en_core_web_sm', disable=['parser','ner'])
doc= nlp(' '.join(bow[0]))
for token in doc:
    print(token, '=>', token.pos_)
# Out:
# vandyke => PROPN
# securecrt => PROPN
# securefx => PROPN
# free => PROPN
# download => PROPN
# vandyke => PROPN
# securecrt => PROPN
# securefx => PROPN
# free => ADJ
# download => NOUN
# full => ADJ
# offline => ADJ
# installer => NOUN
# standalone => PROPN
# setup => NOUN
# vandyke => NOUN
# securecrt => PROPN
# securefx => PROPN
# vandyke => PROPN
# securecrt => PROPN
# securefx => PROPN
# overviewvandyke => PROPN
# securefx => ADJ
# high => ADJ
# speed => NOUN
# secure => ADJ
# file => NOUN
# transfer => NOUN
# application => NOUN
# provides => VERB
# network => NOUN
# administrators => NOUN
# secure => VERB
# remote => ADJ
# access => NOUN
# file => NOUN
# transfer => NOUN
# data => NOUN
# tunneling => NOUN
# across => ADP
# network => NOUN
# reliable => ADJ
# tool => NOUN
# offers => VERB
# robust => ADJ
# security => NOUN
# ssh => NOUN
# extensive => ADJ
# session => NOUN
# management => NOUN
# advanced => ADJ
# scripting => NOUN
# capabilities => NOUN
# allowing => VERB
# raise => VERB
# productivity => NOUN
# next => ADP
# high => ADJ
# level => NOUN
# program => NOUN
# offers => VERB
# advanced => ADJ
# site => NOUN
# synchronization => NOUN
# automation => NOUN
# features => VERB
# help => NOUN
# web => NOUN
# designers => NOUN
# network => NOUN
# administrators => NOUN
# streamline => VERB
# everyday => ADJ
# tasks => NOUN
# program => NOUN
# supports => VERB
# wide => ADJ
# range => NOUN
# popular => ADJ
# protocols => NOUN
# ssh => PROPN
# sftp => PROPN
# ftp => PROPN
# / => PROPN
# tls => PROPN
# scp => PROPN
# thus => ADV
# providing => VERB
# maximum => ADJ
# flexibility => NOUN
# connecting => VERB
# range => NOUN
# remote => ADJ
# servers => NOUN
# easy => ADJ
# use => NOUN
# explorer => NOUN
# like => ADP
# interface => NOUN
# full => ADJ
# support => NOUN
# drag => NOUN
# drop => NOUN
# file => NOUN
# transfers => NOUN
# desktop => NOUN
# applications => NOUN
# also => ADV
# download => VERB
# frostwire => PROPN
# free => PROPN
# download => PROPN
# file => NOUN
# sharing => NOUN
# application => NOUN
# vandyke => NOUN
# securefx => PROPN
# excellent => ADJ
# application => NOUN
# offers => VERB
# wide => ADJ
# range => NOUN
# useful => ADJ
# features => NOUN
# options => NOUN
# responsible => ADJ
# configuring => VERB
# general => ADJ
# software => NOUN
# data => NOUN
# transfer => NOUN
# protocols => NOUN
# uses => VERB
# variety => NOUN
# reliable => ADJ
# robust => ADJ
# algorithms => NOUN
# aes => VERB
# twofish => ADJ
# blowfish => PROPN
# des => PROPN
# ensure => VERB
# strong => ADJ
# data => NOUN
# encryption => NOUN
# thus => ADV
# empowers => VERB
# automate => ADJ
# secure => ADJ
# file => NOUN
# transfers => NOUN
# synchronize => VERB
# local => ADJ
# remote => ADJ
# files => NOUN
# perform => VERB
# server => NOUN
# server => NOUN
# transfers => NOUN
# also => ADV
# facilitates => VERB
# encrypted => VERB
# logons => NOUN
# provides => VERB
# flexible => ADJ
# authentication => NOUN
# options => NOUN
# ensure => VERB
# integrity => NOUN
# message => NOUN
# sent => VERB
# network => NOUN
# program => NOUN
# offers => VERB
# support => NOUN
# multiple => ADJ
# platforms => NOUN
# allowing => VERB
# apply => VERB
# strong => ADJ
# encryption => NOUN
# authentication => NOUN
# mechanism => NOUN
# secure => ADJ
# shell => NOUN
# protocol => NOUN
# secure => ADJ
# network => NOUN
# administration => NOUN
# end => VERB
# user => NOUN
# access => NOUN
# also => ADV
# supports => VERB
# relentless => ADJ
# file => NOUN
# transfers => NOUN
# automatically => ADV
# reconnect => VERB
# resume => NOUN
# transfer => NOUN
# connections => NOUN
# broken => VERB
# also => ADV
# download => VERB
# filezilla => NOUN
# pro => ADJ
# free => ADJ
# download => NOUN
# vandyke => PROPN
# securecrt => PROPN
# securefx => PROPN
# featuresbelow => ADJ
# noticeable => ADJ
# features => NOUN
# experience => NOUN
# vandyke => PROPN
# securecrt => PROPN
# securefx => PROPN
# free => PROPN
# download => NOUN
# high => ADJ
# speed => NOUN
# secure => ADJ
# file => NOUN
# transfer => NOUN
# application => NOUN
# provides => VERB
# network => NOUN
# administrators => NOUN
# secure => VERB
# remote => ADJ
# access => NOUN
# file => NOUN
# transfer => NOUN
# data => NOUN
# tunneling => NOUN
# across => ADP
# network => NOUN
# reliable => ADJ
# tool => NOUN
# offers => VERB
# robust => ADJ
# security => NOUN
# ssh => NOUN
# extensive => ADJ
# session => NOUN
# management => NOUN
# advanced => ADJ
# scripting => NOUN
# capabilities => NOUN
# allowing => VERB
# raise => VERB
# productivity => NOUN
# next => ADP
# high => ADJ
# level => NOUN
# offers => VERB
# advanced => ADJ
# site => NOUN
# synchronization => NOUN
# automation => NOUN
# features => VERB
# help => NOUN
# web => NOUN
# designers => NOUN
# network => NOUN
# administrators => NOUN
# streamline => VERB
# everyday => ADJ
# tasks => NOUN
# supports => VERB
# wide => ADJ
# range => NOUN
# popular => ADJ
# protocols => NOUN
# ssh => PROPN
# sftp => PROPN
# ftp => PROPN
# / => PROPN
# tls => PROPN
# scp => PROPN
# thus => ADV
# providing => VERB
# maximum => ADJ
# flexibility => NOUN
# connecting => VERB
# range => NOUN
# remote => ADJ
# servers => NOUN
# got => VERB
# easy => ADJ
# use => NOUN
# explorer => NOUN
# like => ADP
# interface => NOUN
# full => ADJ
# support => NOUN
# drag => NOUN
# drop => NOUN
# file => NOUN
# transfers => NOUN
# desktop => NOUN
# applications => NOUN
# provides => VERB
# wide => ADJ
# range => NOUN
# useful => ADJ
# features => NOUN
# options => NOUN
# responsible => ADJ
# configuring => VERB
# general => ADJ
# software => NOUN
# data => NOUN
# transfer => NOUN
# protocols => NOUN
# uses => VERB
# variety => NOUN
# reliable => ADJ
# robust => ADJ
# algorithms => NOUN
# aes => VERB
# twofish => ADJ
# blowfish => PROPN
# des => PROPN
# ensure => VERB
# strong => ADJ
# data => NOUN
# encryption => NOUN
# empowers => NOUN
# automate => VERB
# secure => ADJ
# file => NOUN
# transfers => NOUN
# synchronize => VERB
# local => ADJ
# remote => ADJ
# files => NOUN
# perform => VERB
# server => NOUN
# server => NOUN
# transfers => NOUN
# facilitates => NOUN
# encrypted => VERB
# logons => NOUN
# provides => VERB
# flexible => ADJ
# authentication => NOUN
# options => NOUN
# ensure => VERB
# integrity => NOUN
# message => NOUN
# sent => VERB
# network => NOUN
# offers => VERB
# support => NOUN
# multiple => ADJ
# platforms => NOUN
# allowing => VERB
# apply => VERB
# strong => ADJ
# encryption => NOUN
# authentication => NOUN
# mechanism => NOUN
# secure => ADJ
# shell => NOUN
# protocol => NOUN
# secure => ADJ
# network => NOUN
# administration => NOUN
# end => VERB
# user => NOUN
# access => NOUN
# supports => VERB
# relentless => ADJ
# file => NOUN
# transfers => NOUN
# automatically => ADV
# reconnect => VERB
# resume => NOUN
# transfer => NOUN
# connections => NOUN
# broken => VERB
# vandyke => PROPN
# securecrt => PROPN
# securefx => PROPN
# technical => ADJ
# setup => NOUN
# detailsprior => ADJ
# start => NOUN
# vandyke => PROPN
# securecrt => PROPN
# securefx => PROPN
# free => ADJ
# download => NOUN
# ensure => VERB
# availability => NOUN
# listed => VERB
# system => NOUN
# specificationssoftware => NOUN
# full => ADJ
# name => NOUN
# vandyke => NOUN
# securecrt => NOUN
# securefx => PROPN
# setup => NOUN
# file => NOUN
# name => NOUN
# vandyke => NOUN
# securecrt => NOUN
# securefx => PROPN
# build => NOUN
# rarsetup => VERB
# size => NOUN
# mbsetup => NOUN
# type => NOUN
# offline => ADJ
# installer => NOUN
# full => ADJ
# standalone => ADJ
# setupcompatibility => NOUN
# mechanical => ADJ
# bit => NOUN
# bit => NOUN
# latest => ADJ
# version => NOUN
# release => NOUN
# added => VERB
# apr => PROPN
# developers => NOUN
# vandyke => PROPN
# securecrtsystem => NOUN
# requirements => NOUN
# vandyke => PROPN
# securecrt => PROPN
# securefx => ADJ
# operating => NOUN
# system => NOUN
# windows => VERB
# xp => PROPN
# / => SYM
# vista/ => PROPN
# ram => VERB
# mbhard => NOUN
# disk => NOUN
# mbprocessor => NOUN
# intel => PROPN
# pentium => NOUN
# higher => ADJ
# processorvandyke => NOUN
# securecrt => NOUN
# securefx => PROPN
# free => PROPN
# downloadclick => PROPN
# link => PROPN
# start => VERB
# vandyke => PROPN
# securecrt => PROPN
# securefx => PROPN
# free => ADJ
# download => NOUN
# full => ADJ
# offline => ADJ
# installer => NOUN
# standalone => PROPN
# setup => NOUN
# windows => VERB
# operating => NOUN
# system => NOUN
# would => AUX
# compatible => VERB
# bit => NOUN
# bit => NOUN
# windows => NOUN
# installing => VERB
# software => NOUN
# must => AUX
# watch => VERB
# installation => NOUN
# guide => NOUN
# video => NOUN
# download => NOUN
# full => ADJ
# setup => NOUN
# build => NOUN
# password => PROPN
# sitemidas => PROPN
# meshfree => PROPN
# free => PROPN
# downloadsonokinetic => PROPN
# kemence => PROPN
# kontakt => PROPN
# free => PROPN
# downloadcomsol => NOUN
# multiphysics => PROPN
# free => ADJ
# downloadveritas => NOUN
# system => NOUN
# recovery => NOUN
# free => ADJ
# downloadgeometric => ADJ
# glovius => NOUN
# pro => ADJ
# free => ADJ
# downloadwinrar => PROPN
# final => ADJ
# free => ADJ
# downloadthis => DET
# post => NOUN
# last => ADJ
# updated => VERB
# april => PROPN
# vandyke => PROPN
# securecrt => PROPN
# securefx => PROPN
# free => ADJ
# download => NOUN
# full => ADJ
# offline => ADJ
# installer => NOUN
# standalone => PROPN
# setup => NOUN
# vandyke => NOUN
# securecrt => PROPN
# securefx => PROPN
# vandyke => PROPN
# securecrt => PROPN
# securefx => PROPN
# overviewvandyke => PROPN
# securefx => ADJ
# high => ADJ
# speed => NOUN
# secure => ADJ
# file => NOUN
# transfer => NOUN
# application => NOUN
# provides => VERB
# network => NOUN
# administrators => NOUN
# secure => VERB
# remote => ADJ
# access => NOUN
# file => NOUN
# transfer => NOUN
# data => NOUN
# tunneling => NOUN
# across => ADP
# network => NOUN
# reliable => ADJ
# tool => NOUN
# offers => VERB
# robust => ADJ
# security => NOUN
# ssh => NOUN
# extensive => ADJ
# session => NOUN
# management => NOUN
# advanced => ADJ
# scripting => NOUN
# capabilities => NOUN
# allowing => VERB
# raise => VERB
# productivity => NOUN
# next => ADP
# high => ADJ
# level => NOUN
# program => NOUN
# offers => VERB
# advanced => ADJ
# site => NOUN
# synchronization => NOUN
# automation => NOUN
# features => VERB
# help => NOUN
# web => NOUN
# designers => NOUN
# network => NOUN
# administrators => NOUN
# streamline => VERB
# everyday => ADJ
# tasks => NOUN
# program => NOUN
# supports => VERB
# wide => ADJ
# range => NOUN
# popular => ADJ
# protocols => NOUN
# ssh => PROPN
# sftp => PROPN
# ftp => PROPN
# / => PROPN
# tls => PROPN
# scp => PROPN
# thus => ADV
# providing => VERB
# maximum => ADJ
# flexibility => NOUN
# connecting => VERB
# range => NOUN
# remote => ADJ
# servers => NOUN
# easy => ADJ
# use => NOUN
# explorer => NOUN
# like => ADP
# interface => NOUN
# full => ADJ
# support => NOUN
# drag => NOUN
# drop => NOUN
# file => NOUN
# transfers => NOUN
# desktop => NOUN
# applications => NOUN
# also => ADV
# download => VERB
# frostwire => PROPN
# free => PROPN
# download => PROPN
# file => NOUN
# sharing => NOUN
# application => NOUN
# vandyke => NOUN
# securefx => PROPN
# excellent => ADJ
# application => NOUN
# offers => VERB
# wide => ADJ
# range => NOUN
# useful => ADJ
# features => NOUN
# options => NOUN
# responsible => ADJ
# configuring => VERB
# general => ADJ
# software => NOUN
# data => NOUN
# transfer => NOUN
# protocols => NOUN
# uses => VERB
# variety => NOUN
# reliable => ADJ
# robust => ADJ
# algorithms => NOUN
# aes => VERB
# twofish => ADJ
# blowfish => PROPN
# des => PROPN
# ensure => VERB
# strong => ADJ
# data => NOUN
# encryption => NOUN
# thus => ADV
# empowers => VERB
# automate => ADJ
# secure => ADJ
# file => NOUN
# transfers => NOUN
# synchronize => VERB
# local => ADJ
# remote => ADJ
# files => NOUN
# perform => VERB
# server => NOUN
# server => NOUN
# transfers => NOUN
# also => ADV
# facilitates => VERB
# encrypted => VERB
# logons => NOUN
# provides => VERB
# flexible => ADJ
# authentication => NOUN
# options => NOUN
# ensure => VERB
# integrity => NOUN
# message => NOUN
# sent => VERB
# network => NOUN
# program => NOUN
# offers => VERB
# support => NOUN
# multiple => ADJ
# platforms => NOUN
# allowing => VERB
# apply => VERB
# strong => ADJ
# encryption => NOUN
# authentication => NOUN
# mechanism => NOUN
# secure => ADJ
# shell => NOUN
# protocol => NOUN
# secure => ADJ
# network => NOUN
# administration => NOUN
# end => VERB
# user => NOUN
# access => NOUN
# also => ADV
# supports => VERB
# relentless => ADJ
# file => NOUN
# transfers => NOUN
# automatically => ADV
# reconnect => VERB
# resume => NOUN
# transfer => NOUN
# connections => NOUN
# broken => VERB
# also => ADV
# download => VERB
# filezilla => NOUN
# pro => ADJ
# free => ADJ
# download => NOUN
# vandyke => PROPN
# securecrt => PROPN
# securefx => PROPN
# featuresbelow => ADJ
# noticeable => ADJ
# features => NOUN
# experience => NOUN
# vandyke => PROPN
# securecrt => PROPN
# securefx => PROPN
# free => PROPN
# download => NOUN
# high => ADJ
# speed => NOUN
# secure => ADJ
# file => NOUN
# transfer => NOUN
# application => NOUN
# provides => VERB
# network => NOUN
# administrators => NOUN
# secure => VERB
# remote => ADJ
# access => NOUN
# file => NOUN
# transfer => NOUN
# data => NOUN
# tunneling => NOUN
# across => ADP
# network => NOUN
# reliable => ADJ
# tool => NOUN
# offers => VERB
# robust => ADJ
# security => NOUN
# ssh => NOUN
# extensive => ADJ
# session => NOUN
# management => NOUN
# advanced => ADJ
# scripting => NOUN
# capabilities => NOUN
# allowing => VERB
# raise => VERB
# productivity => NOUN
# next => ADP
# high => ADJ
# level => NOUN
# offers => VERB
# advanced => ADJ
# site => NOUN
# synchronization => NOUN
# automation => NOUN
# features => VERB
# help => NOUN
# web => NOUN
# designers => NOUN
# network => NOUN
# administrators => NOUN
# streamline => VERB
# everyday => ADJ
# tasks => NOUN
# supports => VERB
# wide => ADJ
# range => NOUN
# popular => ADJ
# protocols => NOUN
# ssh => PROPN
# sftp => PROPN
# ftp => PROPN
# / => PROPN
# tls => PROPN
# scp => PROPN
# thus => ADV
# providing => VERB
# maximum => ADJ
# flexibility => NOUN
# connecting => VERB
# range => NOUN
# remote => ADJ
# servers => NOUN
# got => VERB
# easy => ADJ
# use => NOUN
# explorer => NOUN
# like => ADP
# interface => NOUN
# full => ADJ
# support => NOUN
# drag => NOUN
# drop => NOUN
# file => NOUN
# transfers => NOUN
# desktop => NOUN
# applications => NOUN
# provides => VERB
# wide => ADJ
# range => NOUN
# useful => ADJ
# features => NOUN
# options => NOUN
# responsible => ADJ
# configuring => VERB
# general => ADJ
# software => NOUN
# data => NOUN
# transfer => NOUN
# protocols => NOUN
# uses => VERB
# variety => NOUN
# reliable => ADJ
# robust => ADJ
# algorithms => NOUN
# aes => VERB
# twofish => ADJ
# blowfish => PROPN
# des => PROPN
# ensure => VERB
# strong => ADJ
# data => NOUN
# encryption => NOUN
# empowers => NOUN
# automate => VERB
# secure => ADJ
# file => NOUN
# transfers => NOUN
# synchronize => VERB
# local => ADJ
# remote => ADJ
# files => NOUN
# perform => VERB
# server => NOUN
# server => NOUN
# transfers => NOUN
# facilitates => NOUN
# encrypted => VERB
# logons => NOUN
# provides => VERB
# flexible => ADJ
# authentication => NOUN
# options => NOUN
# ensure => VERB
# integrity => NOUN
# message => NOUN
# sent => VERB
# network => NOUN
# offers => VERB
# support => NOUN
# multiple => ADJ
# platforms => NOUN
# allowing => VERB
# apply => VERB
# strong => ADJ
# encryption => NOUN
# authentication => NOUN
# mechanism => NOUN
# secure => ADJ
# shell => NOUN
# protocol => NOUN
# secure => ADJ
# network => NOUN
# administration => NOUN
# end => VERB
# user => NOUN
# access => NOUN
# supports => VERB
# relentless => ADJ
# file => NOUN
# transfers => NOUN
# automatically => ADV
# reconnect => VERB
# resume => NOUN
# transfer => NOUN
# connections => NOUN
# broken => VERB
# vandyke => PROPN
# securecrt => PROPN
# securefx => PROPN
# technical => ADJ
# setup => NOUN
# detailsprior => ADJ
# start => NOUN
# vandyke => PROPN
# securecrt => PROPN
# securefx => PROPN
# free => ADJ
# download => NOUN
# ensure => VERB
# availability => NOUN
# listed => VERB
# system => NOUN
# specificationssoftware => NOUN
# full => ADJ
# name => NOUN
# vandyke => NOUN
# securecrt => NOUN
# securefx => PROPN
# setup => NOUN
# file => NOUN
# name => NOUN
# vandyke => NOUN
# securecrt => NOUN
# securefx => PROPN
# build => NOUN
# rarsetup => VERB
# size => NOUN
# mbsetup => NOUN
# type => NOUN
# offline => ADJ
# installer => NOUN
# full => ADJ
# standalone => ADJ
# setupcompatibility => NOUN
# mechanical => ADJ
# bit => NOUN
# bit => NOUN
# latest => ADJ
# version => NOUN
# release => NOUN
# added => VERB
# apr => PROPN
# developers => NOUN
# vandyke => PROPN
# securecrtsystem => NOUN
# requirements => NOUN
# vandyke => PROPN
# securecrt => PROPN
# securefx => ADJ
# operating => NOUN
# system => NOUN
# windows => VERB
# xp => PROPN
# / => SYM
# vista/ => PROPN
# ram => VERB
# mbhard => NOUN
# disk => NOUN
# mbprocessor => NOUN
# intel => PROPN
# pentium => NOUN
# higher => ADJ
# processorvandyke => NOUN
# securecrt => NOUN
# securefx => PROPN
# free => PROPN
# downloadclick => PROPN
# link => PROPN
# start => VERB
# vandyke => PROPN
# securecrt => PROPN
# securefx => PROPN
# free => ADJ
# download => NOUN
# full => ADJ
# offline => ADJ
# installer => NOUN
# standalone => PROPN
# setup => NOUN
# windows => VERB
# operating => NOUN
# system => NOUN
# would => AUX
# compatible => VERB
# bit => NOUN
# bit => NOUN
# windows => NOUN
# installing => VERB
# software => NOUN
# must => AUX
# watch => VERB
# installation => NOUN
# guide => NOUN
# video => NOUN
# download => NOUN
# full => ADJ
# setup => NOUN
# build => NOUN
# password => PROPN
# sitemidas => PROPN
# meshfree => PROPN
# free => PROPN
# downloadsonokinetic => PROPN
# kemence => PROPN
# kontakt => PROPN
# free => PROPN
# downloadcomsol => NOUN
# multiphysics => PROPN
# free => ADJ
# downloadveritas => NOUN
# system => NOUN
# recovery => NOUN
# free => ADJ
# downloadgeometric => ADJ
# glovius => NOUN
# pro => ADJ
# free => ADJ
# downloadwinrar => PROPN
# final => ADJ
# free => ADJ
# downloadthis => DET
# post => NOUN
# last => ADJ
# updated => VERB
# april => PROPN
# download => NOUN
# full => ADJ
# setup => NOUN
# build => PROPN
# sitemidas => PROPN
# meshfree => PROPN
# free => ADJ
# downloadsonokinetic => PROPN
# kemence => PROPN
# kontakt => PROPN
# free => PROPN
# downloadcomsol => NOUN
# multiphysics => PROPN
# free => ADJ
# downloadveritas => NOUN
# system => NOUN
# recovery => NOUN
# free => ADJ
# downloadgeometric => ADJ
# glovius => NOUN
# pro => ADJ
# free => ADJ
# downloadwinrar => PROPN
# final => ADJ
# free => ADJ
# download => NOUN
# sitemidas => VERB
# meshfree => PROPN
# free => ADJ
# downloadsonokinetic => PROPN
# kemence => PROPN
# kontakt => PROPN
# free => PROPN
# downloadcomsol => NOUN
# multiphysics => PROPN
# free => ADJ
# downloadveritas => NOUN
# system => NOUN
# recovery => NOUN
# free => ADJ
# downloadgeometric => ADJ
# glovius => NOUN
# pro => ADJ
# free => ADJ
# downloadwinrar => PROPN
# final => ADJ
# free => ADJ
# download => NOUN

# %%
#now lemmatizing the whole corpus so that we can reach to the  root words

def lemmatization(texts, tags=['NOUN','ADJ','VERB','ADV','PROPN']):
    texts_out= []
    for sent in texts:
        doc= nlp(" ".join(sent))
        texts_out.append([token.lemma_ for token in doc if token.pos_ in tags])
    return texts_out

# %%
bag_of_words = lemmatization(bow)

# %%
#this gives us the keywords
bag_of_words
# Out:
# [['vandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'download',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'download',
#   'full',
#   'offline',
#   'installer',
#   'standalone',
#   'setup',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'overviewvandyke',
#   'securefx',
#   'high',
#   'speed',
#   'secure',
#   'file',
#   'transfer',
#   'application',
#   'provide',
#   'network',
#   'administrator',
#   'secure',
#   'remote',
#   'access',
#   'file',
#   'transfer',
#   'datum',
#   'tunneling',
#   'network',
#   'reliable',
#   'tool',
#   'offer',
#   'robust',
#   'security',
#   'ssh',
#   'extensive',
#   'session',
#   'management',
#   'advanced',
#   'scripting',
#   'capability',
#   'allow',
#   'raise',
#   'productivity',
#   'high',
#   'level',
#   'program',
#   'offer',
#   'advanced',
#   'site',
#   'synchronization',
#   'automation',
#   'feature',
#   'help',
#   'web',
#   'designer',
#   'network',
#   'administrator',
#   'streamline',
#   'everyday',
#   'task',
#   'program',
#   'support',
#   'wide',
#   'range',
#   'popular',
#   'protocol',
#   'ssh',
#   'sftp',
#   'ftp',
#   '/',
#   'tls',
#   'scp',
#   'thus',
#   'provide',
#   'maximum',
#   'flexibility',
#   'connect',
#   'range',
#   'remote',
#   'server',
#   'easy',
#   'use',
#   'explorer',
#   'interface',
#   'full',
#   'support',
#   'drag',
#   'drop',
#   'file',
#   'transfer',
#   'desktop',
#   'application',
#   'also',
#   'download',
#   'frostwire',
#   'free',
#   'download',
#   'file',
#   'sharing',
#   'application',
#   'vandyke',
#   'securefx',
#   'excellent',
#   'application',
#   'offer',
#   'wide',
#   'range',
#   'useful',
#   'feature',
#   'option',
#   'responsible',
#   'configure',
#   'general',
#   'software',
#   'datum',
#   'transfer',
#   'protocol',
#   'use',
#   'variety',
#   'reliable',
#   'robust',
#   'algorithm',
#   'aes',
#   'twofish',
#   'blowfish',
#   'des',
#   'ensure',
#   'strong',
#   'datum',
#   'encryption',
#   'thus',
#   'empower',
#   'automate',
#   'secure',
#   'file',
#   'transfer',
#   'synchronize',
#   'local',
#   'remote',
#   'file',
#   'perform',
#   'server',
#   'server',
#   'transfer',
#   'also',
#   'facilitate',
#   'encrypt',
#   'logon',
#   'provide',
#   'flexible',
#   'authentication',
#   'option',
#   'ensure',
#   'integrity',
#   'message',
#   'send',
#   'network',
#   'program',
#   'offer',
#   'support',
#   'multiple',
#   'platform',
#   'allow',
#   'apply',
#   'strong',
#   'encryption',
#   'authentication',
#   'mechanism',
#   'secure',
#   'shell',
#   'protocol',
#   'secure',
#   'network',
#   'administration',
#   'end',
#   'user',
#   'access',
#   'also',
#   'support',
#   'relentless',
#   'file',
#   'transfer',
#   'automatically',
#   'reconnect',
#   'resume',
#   'transfer',
#   'connection',
#   'break',
#   'also',
#   'download',
#   'filezilla',
#   'pro',
#   'free',
#   'download',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'featuresbelow',
#   'noticeable',
#   'feature',
#   'experience',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'download',
#   'high',
#   'speed',
#   'secure',
#   'file',
#   'transfer',
#   'application',
#   'provide',
#   'network',
#   'administrator',
#   'secure',
#   'remote',
#   'access',
#   'file',
#   'transfer',
#   'datum',
#   'tunneling',
#   'network',
#   'reliable',
#   'tool',
#   'offer',
#   'robust',
#   'security',
#   'ssh',
#   'extensive',
#   'session',
#   'management',
#   'advanced',
#   'scripting',
#   'capability',
#   'allow',
#   'raise',
#   'productivity',
#   'high',
#   'level',
#   'offer',
#   'advanced',
#   'site',
#   'synchronization',
#   'automation',
#   'feature',
#   'help',
#   'web',
#   'designer',
#   'network',
#   'administrator',
#   'streamline',
#   'everyday',
#   'task',
#   'support',
#   'wide',
#   'range',
#   'popular',
#   'protocol',
#   'ssh',
#   'sftp',
#   'ftp',
#   '/',
#   'tls',
#   'scp',
#   'thus',
#   'provide',
#   'maximum',
#   'flexibility',
#   'connect',
#   'range',
#   'remote',
#   'server',
#   'get',
#   'easy',
#   'use',
#   'explorer',
#   'interface',
#   'full',
#   'support',
#   'drag',
#   'drop',
#   'file',
#   'transfer',
#   'desktop',
#   'application',
#   'provide',
#   'wide',
#   'range',
#   'useful',
#   'feature',
#   'option',
#   'responsible',
#   'configure',
#   'general',
#   'software',
#   'datum',
#   'transfer',
#   'protocol',
#   'use',
#   'variety',
#   'reliable',
#   'robust',
#   'algorithm',
#   'aes',
#   'twofish',
#   'blowfish',
#   'des',
#   'ensure',
#   'strong',
#   'datum',
#   'encryption',
#   'empower',
#   'automate',
#   'secure',
#   'file',
#   'transfer',
#   'synchronize',
#   'local',
#   'remote',
#   'file',
#   'perform',
#   'server',
#   'server',
#   'transfer',
#   'facilitate',
#   'encrypt',
#   'logon',
#   'provide',
#   'flexible',
#   'authentication',
#   'option',
#   'ensure',
#   'integrity',
#   'message',
#   'send',
#   'network',
#   'offer',
#   'support',
#   'multiple',
#   'platform',
#   'allow',
#   'apply',
#   'strong',
#   'encryption',
#   'authentication',
#   'mechanism',
#   'secure',
#   'shell',
#   'protocol',
#   'secure',
#   'network',
#   'administration',
#   'end',
#   'user',
#   'access',
#   'support',
#   'relentless',
#   'file',
#   'transfer',
#   'automatically',
#   'reconnect',
#   'resume',
#   'transfer',
#   'connection',
#   'break',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'technical',
#   'setup',
#   'detailsprior',
#   'start',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'download',
#   'ensure',
#   'availability',
#   'list',
#   'system',
#   'specificationssoftware',
#   'full',
#   'name',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'setup',
#   'file',
#   'name',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'build',
#   'rarsetup',
#   'size',
#   'mbsetup',
#   'type',
#   'offline',
#   'installer',
#   'full',
#   'standalone',
#   'setupcompatibility',
#   'mechanical',
#   'bit',
#   'bit',
#   'late',
#   'version',
#   'release',
#   'add',
#   'apr',
#   'developer',
#   'vandyke',
#   'securecrtsystem',
#   'requirement',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'operating',
#   'system',
#   'window',
#   'xp',
#   'vista/',
#   'ram',
#   'mbhard',
#   'disk',
#   'mbprocessor',
#   'intel',
#   'pentium',
#   'high',
#   'processorvandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'downloadclick',
#   'link',
#   'start',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'download',
#   'full',
#   'offline',
#   'installer',
#   'standalone',
#   'setup',
#   'window',
#   'operating',
#   'system',
#   'compatible',
#   'bit',
#   'bit',
#   'window',
#   'instal',
#   'software',
#   'watch',
#   'installation',
#   'guide',
#   'video',
#   'download',
#   'full',
#   'setup',
#   'build',
#   'password',
#   'sitemidas',
#   'meshfree',
#   'free',
#   'downloadsonokinetic',
#   'kemence',
#   'kontakt',
#   'free',
#   'downloadcomsol',
#   'multiphysics',
#   'free',
#   'downloadveritas',
#   'system',
#   'recovery',
#   'free',
#   'downloadgeometric',
#   'glovius',
#   'pro',
#   'free',
#   'downloadwinrar',
#   'final',
#   'free',
#   'post',
#   'last',
#   'update',
#   'april',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'download',
#   'full',
#   'offline',
#   'installer',
#   'standalone',
#   'setup',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'overviewvandyke',
#   'securefx',
#   'high',
#   'speed',
#   'secure',
#   'file',
#   'transfer',
#   'application',
#   'provide',
#   'network',
#   'administrator',
#   'secure',
#   'remote',
#   'access',
#   'file',
#   'transfer',
#   'datum',
#   'tunneling',
#   'network',
#   'reliable',
#   'tool',
#   'offer',
#   'robust',
#   'security',
#   'ssh',
#   'extensive',
#   'session',
#   'management',
#   'advanced',
#   'scripting',
#   'capability',
#   'allow',
#   'raise',
#   'productivity',
#   'high',
#   'level',
#   'program',
#   'offer',
#   'advanced',
#   'site',
#   'synchronization',
#   'automation',
#   'feature',
#   'help',
#   'web',
#   'designer',
#   'network',
#   'administrator',
#   'streamline',
#   'everyday',
#   'task',
#   'program',
#   'support',
#   'wide',
#   'range',
#   'popular',
#   'protocol',
#   'ssh',
#   'sftp',
#   'ftp',
#   '/',
#   'tls',
#   'scp',
#   'thus',
#   'provide',
#   'maximum',
#   'flexibility',
#   'connect',
#   'range',
#   'remote',
#   'server',
#   'easy',
#   'use',
#   'explorer',
#   'interface',
#   'full',
#   'support',
#   'drag',
#   'drop',
#   'file',
#   'transfer',
#   'desktop',
#   'application',
#   'also',
#   'download',
#   'frostwire',
#   'free',
#   'download',
#   'file',
#   'sharing',
#   'application',
#   'vandyke',
#   'securefx',
#   'excellent',
#   'application',
#   'offer',
#   'wide',
#   'range',
#   'useful',
#   'feature',
#   'option',
#   'responsible',
#   'configure',
#   'general',
#   'software',
#   'datum',
#   'transfer',
#   'protocol',
#   'use',
#   'variety',
#   'reliable',
#   'robust',
#   'algorithm',
#   'aes',
#   'twofish',
#   'blowfish',
#   'des',
#   'ensure',
#   'strong',
#   'datum',
#   'encryption',
#   'thus',
#   'empower',
#   'automate',
#   'secure',
#   'file',
#   'transfer',
#   'synchronize',
#   'local',
#   'remote',
#   'file',
#   'perform',
#   'server',
#   'server',
#   'transfer',
#   'also',
#   'facilitate',
#   'encrypt',
#   'logon',
#   'provide',
#   'flexible',
#   'authentication',
#   'option',
#   'ensure',
#   'integrity',
#   'message',
#   'send',
#   'network',
#   'program',
#   'offer',
#   'support',
#   'multiple',
#   'platform',
#   'allow',
#   'apply',
#   'strong',
#   'encryption',
#   'authentication',
#   'mechanism',
#   'secure',
#   'shell',
#   'protocol',
#   'secure',
#   'network',
#   'administration',
#   'end',
#   'user',
#   'access',
#   'also',
#   'support',
#   'relentless',
#   'file',
#   'transfer',
#   'automatically',
#   'reconnect',
#   'resume',
#   'transfer',
#   'connection',
#   'break',
#   'also',
#   'download',
#   'filezilla',
#   'pro',
#   'free',
#   'download',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'featuresbelow',
#   'noticeable',
#   'feature',
#   'experience',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'download',
#   'high',
#   'speed',
#   'secure',
#   'file',
#   'transfer',
#   'application',
#   'provide',
#   'network',
#   'administrator',
#   'secure',
#   'remote',
#   'access',
#   'file',
#   'transfer',
#   'datum',
#   'tunneling',
#   'network',
#   'reliable',
#   'tool',
#   'offer',
#   'robust',
#   'security',
#   'ssh',
#   'extensive',
#   'session',
#   'management',
#   'advanced',
#   'scripting',
#   'capability',
#   'allow',
#   'raise',
#   'productivity',
#   'high',
#   'level',
#   'offer',
#   'advanced',
#   'site',
#   'synchronization',
#   'automation',
#   'feature',
#   'help',
#   'web',
#   'designer',
#   'network',
#   'administrator',
#   'streamline',
#   'everyday',
#   'task',
#   'support',
#   'wide',
#   'range',
#   'popular',
#   'protocol',
#   'ssh',
#   'sftp',
#   'ftp',
#   '/',
#   'tls',
#   'scp',
#   'thus',
#   'provide',
#   'maximum',
#   'flexibility',
#   'connect',
#   'range',
#   'remote',
#   'server',
#   'get',
#   'easy',
#   'use',
#   'explorer',
#   'interface',
#   'full',
#   'support',
#   'drag',
#   'drop',
#   'file',
#   'transfer',
#   'desktop',
#   'application',
#   'provide',
#   'wide',
#   'range',
#   'useful',
#   'feature',
#   'option',
#   'responsible',
#   'configure',
#   'general',
#   'software',
#   'datum',
#   'transfer',
#   'protocol',
#   'use',
#   'variety',
#   'reliable',
#   'robust',
#   'algorithm',
#   'aes',
#   'twofish',
#   'blowfish',
#   'des',
#   'ensure',
#   'strong',
#   'datum',
#   'encryption',
#   'empower',
#   'automate',
#   'secure',
#   'file',
#   'transfer',
#   'synchronize',
#   'local',
#   'remote',
#   'file',
#   'perform',
#   'server',
#   'server',
#   'transfer',
#   'facilitate',
#   'encrypt',
#   'logon',
#   'provide',
#   'flexible',
#   'authentication',
#   'option',
#   'ensure',
#   'integrity',
#   'message',
#   'send',
#   'network',
#   'offer',
#   'support',
#   'multiple',
#   'platform',
#   'allow',
#   'apply',
#   'strong',
#   'encryption',
#   'authentication',
#   'mechanism',
#   'secure',
#   'shell',
#   'protocol',
#   'secure',
#   'network',
#   'administration',
#   'end',
#   'user',
#   'access',
#   'support',
#   'relentless',
#   'file',
#   'transfer',
#   'automatically',
#   'reconnect',
#   'resume',
#   'transfer',
#   'connection',
#   'break',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'technical',
#   'setup',
#   'detailsprior',
#   'start',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'download',
#   'ensure',
#   'availability',
#   'list',
#   'system',
#   'specificationssoftware',
#   'full',
#   'name',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'setup',
#   'file',
#   'name',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'build',
#   'rarsetup',
#   'size',
#   'mbsetup',
#   'type',
#   'offline',
#   'installer',
#   'full',
#   'standalone',
#   'setupcompatibility',
#   'mechanical',
#   'bit',
#   'bit',
#   'late',
#   'version',
#   'release',
#   'add',
#   'apr',
#   'developer',
#   'vandyke',
#   'securecrtsystem',
#   'requirement',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'operating',
#   'system',
#   'window',
#   'xp',
#   'vista/',
#   'ram',
#   'mbhard',
#   'disk',
#   'mbprocessor',
#   'intel',
#   'pentium',
#   'high',
#   'processorvandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'downloadclick',
#   'link',
#   'start',
#   'vandyke',
#   'securecrt',
#   'securefx',
#   'free',
#   'download',
#   'full',
#   'offline',
#   'installer',
#   'standalone',
#   'setup',
#   'window',
#   'operating',
#   'system',
#   'compatible',
#   'bit',
#   'bit',
#   'window',
#   'instal',
#   'software',
#   'watch',
#   'installation',
#   'guide',
#   'video',
#   'download',
#   'full',
#   'setup',
#   'build',
#   'password',
#   'sitemidas',
#   'meshfree',
#   'free',
#   'downloadsonokinetic',
#   'kemence',
#   'kontakt',
#   'free',
#   'downloadcomsol',
#   'multiphysics',
#   'free',
#   'downloadveritas',
#   'system',
#   'recovery',
#   'free',
#   'downloadgeometric',
#   'glovius',
#   'pro',
#   'free',
#   'downloadwinrar',
#   'final',
#   'free',
#   'post',
#   'last',
#   'update',
#   ...]]

# %%
from gensim import corpora
id2word = corpora.Dictionary(bag_of_words)
print(id2word)
# Out:
# Dictionary(186 unique tokens: ['/', 'access', 'add', 'administration', 'administrator']...)
